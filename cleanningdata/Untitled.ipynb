# %%
import numpy as np
import pandas as pd
df_train = pd.read_csv('../crawldata/hcm.csv')

# %%
df_train.head(10)
# Out:
#    bed  bath    area  budget   price      local_street         local_ward  \
# 0    7     4   34.60   13.50  390.17      Đ.Hùng Vương                P.1
# 1    3     3   31.10    6.00  192.92   Đ.Đoàn Thị Điểm                P.1
# 2    7    11  177.80   35.00  196.85       Đ.Hậu Giang                P.4
# 3    4     4   87.50    5.15   58.85        Đ.Vườn Lài      P.An Phú Đông
# 4    4     3   51.70    5.95  115.08    Đ.Âu Dương Lân                P.3
# 5    4     4   49.90    6.45  129.25    Đ.Phan Huy Ích               P.14
# 6    2     2   44.20    4.95  111.99   Đ.Nơ Trang Long               P.12
# 7    3     3   50.10    5.35  106.78           Đ.Số 12  P.Hiệp Bình Phước
# 8    2     3   22.30    5.15  230.94  Đ.Phùng Văn Cung                P.2
# 9    4     3   84.42    6.55   77.58    Đ.Phan Huy Ích               P.14
#
#   local_district   local_city
# 0           Q.10  Hồ Chí Minh
# 1    Q.Phú Nhuận  Hồ Chí Minh
# 2     Q.Tân Bình  Hồ Chí Minh
# ...

# %%
df_train = df_train.drop('local_city',1)
df_train.head()
# Out:
#    bed  bath   area  budget   price     local_street     local_ward  \
# 0    7     4   34.6   13.50  390.17     Đ.Hùng Vương            P.1
# 1    3     3   31.1    6.00  192.92  Đ.Đoàn Thị Điểm            P.1
# 2    7    11  177.8   35.00  196.85      Đ.Hậu Giang            P.4
# 3    4     4   87.5    5.15   58.85       Đ.Vườn Lài  P.An Phú Đông
# 4    4     3   51.7    5.95  115.08   Đ.Âu Dương Lân            P.3
#
#   local_district
# 0           Q.10
# 1    Q.Phú Nhuận
# 2     Q.Tân Bình
# 3           Q.12
# 4            Q.8

# %%
df_train['local'] = df_train['local_street']+df_train['local_ward']+df_train['local_district']

# %%
df_train
# Out:
#       bed  bath   area  budget   price     local_street     local_ward  \
# 0       7     4   34.6   13.50  390.17     Đ.Hùng Vương            P.1
# 1       3     3   31.1    6.00  192.92  Đ.Đoàn Thị Điểm            P.1
# 2       7    11  177.8   35.00  196.85      Đ.Hậu Giang            P.4
# 3       4     4   87.5    5.15   58.85       Đ.Vườn Lài  P.An Phú Đông
# 4       4     3   51.7    5.95  115.08   Đ.Âu Dương Lân            P.3
# ...   ...   ...    ...     ...     ...              ...            ...
# 6275    7     4   34.6   13.50  390.17     Đ.Hùng Vương            P.1
# 6276    4     4   87.5    5.15   58.85       Đ.Vườn Lài  P.An Phú Đông
# 6277    3     3   31.1    6.00  192.92  Đ.Đoàn Thị Điểm            P.1
# 6278    7    11  177.8   35.00  196.85      Đ.Hậu Giang            P.4
# 6279    2     2   43.9    2.80   63.78  Đ.Hiệp Thành 26   P.Hiệp Thành
#
#      local_district                            local
# 0              Q.10              Đ.Hùng VươngP.1Q.10
# ...

# %%
df_unique = df_train.unique()
df_unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-0dc5ea76560c> in <module>
# ----> 1 df_unique = df_train.unique()
#       2 df_unique
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
for i in df_train['local_street']:
    print(i)
# Out:
# Đ.Hùng Vương
# Đ.Đoàn Thị Điểm
# Đ.Hậu Giang
# Đ.Vườn Lài
# Đ.Âu Dương Lân
# Đ.Phan Huy Ích
# Đ.Nơ Trang Long
# Đ.Số 12
# Đ.Phùng Văn Cung
# Đ.Phan Huy Ích
# Đ.Nguyễn Hiền
# Đ.Ba Tháng Hai
# Đ.Tô Hiến Thành
# Đ.Thích Quảng Đức
# Đ.Số 8
# Đ.Nguyễn Đình Chiểu
# Đ.Nguyễn Văn Đậu
# Đ.28B
# Đ.C1
# Đ.QL13 Cũ
# Ấp 1
# Đ.Âu Dương Lân
# Đ.Phan Huy Ích
# Đ.Nơ Trang Long
# Đ.Số 12
# Đ.Phùng Văn Cung
# Đ.Phan Huy Ích
# Đ.Nguyễn Hiền
# Đ.Ba Tháng Hai
# Đ.Tô Hiến Thành
# Đ.Thích Quảng Đức
# Đ.Số 8
# Đ.Nguyễn Đình Chiểu
# Đ.Nguyễn Văn Đậu
# Đ.28B
# Đ.C1
# Đ.QL13 Cũ
# Ấp 1
# Đ.Hùng Vương
# Đ.Đoàn Thị Điểm
# Đ.Hậu Giang
# Đ.Vườn Lài
# Đ.Hiệp Thành 26
# Đ.Tùng Thiện Vương
# Đ.Nguyễn Tuân
# Đ.Hiệp Thành 13
# Đ.Bùi Văn Thêm
# Đ.Tân Chánh Hiệp 13
# Đ.Âu Dương Lân
# Đ.Phan Huy Ích
# Đ.Nơ Trang Long
# Đ.Số 12
# Đ.Phùng Văn Cung
# Đ.Phan Huy Ích
# Đ.Nguyễn Hiền
# Đ.Ba Tháng Hai
# Đ.Tô Hiến Thành
# Đ.Thích Quảng Đức
# Đ.Số 8
# Đ.Nguyễn Đình Chiểu
# Đ.Nguyễn Văn Đậu
# Đ.28B
# Đ.C1
# Đ.QL13 Cũ
# Ấp 1
# ...

# %%
df_train.head(100)
# Out:
#     bed  bath   area  budget   price        local_street     local_ward  \
# 0     7     4   34.6   13.50  390.17        Đ.Hùng Vương            P.1
# 1     3     3   31.1    6.00  192.92     Đ.Đoàn Thị Điểm            P.1
# 2     7    11  177.8   35.00  196.85         Đ.Hậu Giang            P.4
# 3     4     4   87.5    5.15   58.85          Đ.Vườn Lài  P.An Phú Đông
# 4     4     3   51.7    5.95  115.08      Đ.Âu Dương Lân            P.3
# ..  ...   ...    ...     ...     ...                 ...            ...
# 95    4     4   87.5    5.15   58.85          Đ.Vườn Lài  P.An Phú Đông
# 96    2     2   43.9    2.80   63.78     Đ.Hiệp Thành 26   P.Hiệp Thành
# 97    2     3   25.2    2.40   95.23  Đ.Tùng Thiện Vương           P.11
# 98    1     1   28.1    1.50   53.38       Đ.Nguyễn Tuân            P.3
# 99    2     1   52.9    3.00   56.71     Đ.Hiệp Thành 13   P.Hiệp Thành
#
#    local_district                            local
# 0            Q.10              Đ.Hùng VươngP.1Q.10
# ...
