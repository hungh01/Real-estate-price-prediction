# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('../crawldata/hcm.csv')
df.head(50)
# Out:
#     bed  bath    area  budget   price         local_street         local_ward  \
# 0     7     4   34.60   13.50  390.17         Đ.Hùng Vương                P.1
# 1     3     3   31.10    6.00  192.92      Đ.Đoàn Thị Điểm                P.1
# 2     7    11  177.80   35.00  196.85          Đ.Hậu Giang                P.4
# 3     4     4   87.50    5.15   58.85           Đ.Vườn Lài      P.An Phú Đông
# 4     4     3   51.70    5.95  115.08       Đ.Âu Dương Lân                P.3
# 5     4     4   49.90    6.45  129.25       Đ.Phan Huy Ích               P.14
# 6     2     2   44.20    4.95  111.99      Đ.Nơ Trang Long               P.12
# 7     3     3   50.10    5.35  106.78              Đ.Số 12  P.Hiệp Bình Phước
# 8     2     3   22.30    5.15  230.94     Đ.Phùng Văn Cung                P.2
# 9     4     3   84.42    6.55   77.58       Đ.Phan Huy Ích               P.14
# 10    4     3   36.00    6.65  184.72        Đ.Nguyễn Hiền                P.4
# 11    3     3   50.80    9.60  188.97       Đ.Ba Tháng Hai                P.2
# 12    7     6   43.80    8.36  190.89      Đ.Tô Hiến Thành               P.13
# 13    3     4   28.00    5.85  208.92    Đ.Thích Quảng Đức                P.5
# 14    2     2   55.00    5.75  104.54               Đ.Số 8               P.11
# 15    3     3   24.00    6.10  254.16  Đ.Nguyễn Đình Chiểu                P.4
# 16    3     3   27.90    6.35  227.59     Đ.Nguyễn Văn Đậu               P.11
# 17    3     4   94.20   11.00  116.77                Đ.28B     P.Phước Long B
# 18    8     8  103.60   16.90  163.12                 Đ.C1               P.13
# 19    6     2  237.90   22.00   92.47            Đ.QL13 Cũ  P.Hiệp Bình Phước
# 20    3     2  169.40    4.25   25.08                 Ấp 1          X.Quy Đức
# 21    4     3   51.70    5.95  115.08       Đ.Âu Dương Lân                P.3
# 22    4     4   49.90    6.45  129.25       Đ.Phan Huy Ích               P.14
# 23    2     2   44.20    4.95  111.99      Đ.Nơ Trang Long               P.12
# 24    3     3   50.10    5.35  106.78              Đ.Số 12  P.Hiệp Bình Phước
# 25    2     3   22.30    5.15  230.94     Đ.Phùng Văn Cung                P.2
# 26    4     3   84.42    6.55   77.58       Đ.Phan Huy Ích               P.14
# 27    4     3   36.00    6.65  184.72        Đ.Nguyễn Hiền                P.4
# 28    3     3   50.80    9.60  188.97       Đ.Ba Tháng Hai                P.2
# 29    7     6   43.80    8.36  190.89      Đ.Tô Hiến Thành               P.13
# 30    3     4   28.00    5.85  208.92    Đ.Thích Quảng Đức                P.5
# 31    2     2   55.00    5.75  104.54               Đ.Số 8               P.11
# 32    3     3   24.00    6.10  254.16  Đ.Nguyễn Đình Chiểu                P.4
# 33    3     3   27.90    6.35  227.59     Đ.Nguyễn Văn Đậu               P.11
# 34    3     4   94.20   11.00  116.77                Đ.28B     P.Phước Long B
# 35    8     8  103.60   16.90  163.12                 Đ.C1               P.13
# 36    6     2  237.90   22.00   92.47            Đ.QL13 Cũ  P.Hiệp Bình Phước
# 42           Q.12  Hồ Chí Minh
# 43            Q.8  Hồ Chí Minh
# 44       Q.Gò Vấp  Hồ Chí Minh
# 45           Q.12  Hồ Chí Minh
# 46    Q.Phú Nhuận  Hồ Chí Minh
# 47           Q.12          NaN
# 48            Q.8  Hồ Chí Minh
# 49       Q.Gò Vấp  Hồ Chí Minh

# %%
from pandas import DataFrame
x_train = DataFrame(df,columns = ['bed','bath','area'])
x_train.head(5)
# Out:
#    bed  bath   area
# 0    7     4   34.6
# 1    3     3   31.1
# 2    7    11  177.8
# 3    4     4   87.5
# 4    4     3   51.7

# %%
y_train = df.budget
y_train.head(5)
# Out:
# 0    13.50
# 1     6.00
# 2    35.00
# 3     5.15
# 4     5.95
# Name: budget, dtype: float64

# %%
data_train =DataFrame(df,columns = ['bed','bath','area','budget'])
data_train
# Out:
#       bed  bath   area  budget
# 0       7     4   34.6   13.50
# 1       3     3   31.1    6.00
# 2       7    11  177.8   35.00
# 3       4     4   87.5    5.15
# 4       4     3   51.7    5.95
# ...   ...   ...    ...     ...
# 6275    7     4   34.6   13.50
# 6276    4     4   87.5    5.15
# 6277    3     3   31.1    6.00
# 6278    7    11  177.8   35.00
# 6279    2     2   43.9    2.80
#
# [6280 rows x 4 columns]

# %%
reg = linear_model.LinearRegression().fit(x_train,y_train)

# %%
reg.coef_
# Out:
# array([0.49517783, 1.76470106, 0.06079704])

# %%
reg.intercept_
# Out:
# -3.6938091281531538

# %%
test_df = pd.read_csv("../crawldata/hcmtest.csv")
test_df.head(3)
# Out:
#    bed  bath  area  budget  price        local_street    local_ward  \
# 0    2     3  25.2     2.4  95.23  Đ.Tùng Thiện Vương          P.11
# 1    1     1  28.1     1.5  53.38       Đ.Nguyễn Tuân           P.3
# 2    2     1  52.9     3.0  56.71     Đ.Hiệp Thành 13  P.Hiệp Thành
#
#   local_district   local_city
# 0            Q.8  Hồ Chí Minh
# 1       Q.Gò Vấp  Hồ Chí Minh
# 2           Q.12  Hồ Chí Minh

# %%
x_test = DataFrame(test_df,columns = ['bed','bath','area'])
y_test = DataFrame(test_df,columns = ['budget'])
x_test
# Out:
#      bed  bath  area
# 0      2     3  25.2
# 1      1     1  28.1
# 2      2     1  52.9
# 3      2     2  21.1
# 4      1     1  77.5
# ..   ...   ...   ...
# 864    2     3  25.2
# 865    1     1  28.1
# 866    2     1  52.9
# 867    2     2  21.1
# 868    1     1  77.5
#
# [869 rows x 3 columns]

# %%
reg.score(x_test,y_test)
# Out:
# 0.8226818716273234

# %%
demo_df = pd.read_csv('p1binhthanh.csv')
demo = DataFrame(demo_df,columns = ['bed','bath','area'])
demo.head(3)
# Out:
#    bed  bath  area
# 0    2     3  15.0
# 1    5     5  65.2
# 2    2     2  12.7

# %%
demo['budget_guess']= reg.predict(demo)

# %%
demo[['budget','local_street','local_ward','local_district','local_city']] = demo_df[['budget','local_street','local_ward','local_district','local_city']]
demo
# Out:
#     bed  bath    area  budget_guess  budget       local_street local_ward  \
# 0     2     3   15.00      3.502605    2.30  Đ.Đinh Tiên Hoàng        P.1
# 1     5     5   65.20     11.569553    7.60  Đ.Đinh Tiên Hoàng        P.1
# 2     2     2   12.70      1.598071    1.60  Đ.Đinh Tiên Hoàng        P.1
# 3     2     2   53.50      4.078590    6.50        Đ.Diên Hồng        P.1
# 4     2     2   19.50      2.011491    3.80       lê văn duyệt        P.1
# 5     2     2   25.70      2.388433    3.05  Đ.Đinh Tiên Hoàng        P.1
# 6     3     3   31.40      4.994855    4.30  Đ.Đinh Tiên Hoàng        P.1
# 7     1     1   39.50      0.967553    5.70  Đ.Đinh Tiên Hoàng        P.1
# 8     5     4   85.10     11.014713   24.00   Đ.Trịnh Hoài Đức        P.1
# 9     4     4   62.60      9.151601   17.50       lê văn duyệt        P.1
# 10    2     3   18.10      3.691076    3.20       lê văn duyệt        P.1
# 11    3     2   45.90      4.111711    7.20       lê văn duyệt        P.1
# 12    3     4   32.30      6.814273    7.00  Đ.Đinh Tiên Hoàng        P.1
# 13    3     2   60.50      4.999348    8.50           Đ.Yên Đỗ        P.1
# 14    1     1   38.10      0.882437    5.80       lê văn duyệt        P.1
# 15    3     2   51.10      4.427855    7.00       lê văn duyệt        P.1
# 16    3     2   41.05      3.816845    7.20  Đ.Đinh Tiên Hoàng        P.1
# 17    2     2   20.70      2.084447    5.13       lê văn duyệt        P.1
# 18    2     2   13.00      1.616310    1.93  Đ.Đinh Tiên Hoàng        P.1
# 19    3     3  142.00     11.719008   17.00    Đ.Phó Đức Chính        P.1
# 20    6     5   42.90     10.708956    8.00    Đ.Bùi Hữu Nghĩa        P.1
# 21    2     2   25.70      2.388433    3.05  Đ.Đinh Tiên Hoàng        P.1
# 22    1     2   19.00      1.485915    2.70       lê văn duyệt        P.1
#
#    local_district   local_city
# 0    Q.Bình Thạnh  Hồ Chí Minh
# 1    Q.Bình Thạnh  Hồ Chí Minh
# 2    Q.Bình Thạnh  Hồ Chí Minh
# 3    Q.Bình Thạnh  Hồ Chí Minh
# 4    Q.Bình Thạnh  Hồ Chí Minh
# 5    Q.Bình Thạnh  Hồ Chí Minh
# 6    Q.Bình Thạnh  Hồ Chí Minh
# 7    Q.Bình Thạnh  Hồ Chí Minh
# 8    Q.Bình Thạnh  Hồ Chí Minh
# 9    Q.Bình Thạnh  Hồ Chí Minh
# 10   Q.Bình Thạnh  Hồ Chí Minh
# 11   Q.Bình Thạnh  Hồ Chí Minh
# 12   Q.Bình Thạnh  Hồ Chí Minh
# 13   Q.Bình Thạnh  Hồ Chí Minh
# 14   Q.Bình Thạnh  Hồ Chí Minh
# 15   Q.Bình Thạnh  Hồ Chí Minh
# 16   Q.Bình Thạnh  Hồ Chí Minh
# 17   Q.Bình Thạnh  Hồ Chí Minh
# 18   Q.Bình Thạnh  Hồ Chí Minh
# 19   Q.Bình Thạnh  Hồ Chí Minh
# 20   Q.Bình Thạnh  Hồ Chí Minh
# 21   Q.Bình Thạnh  Hồ Chí Minh
# 22   Q.Bình Thạnh  Hồ Chí Minh

# %%
#demo.to_csv("Guess.csv")
